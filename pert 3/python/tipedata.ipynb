# %% [markdown]
# INT(integer)

# %%
num = 10;
num2 = 10;

print(num + num2)
# Out:
# 20

# %% [markdown]
# String

# %%
name = "hello"
print(name)
print(type(name))

# %% [markdown]
# FLOAT

# %%
c = 10.5
print(c)
print(type(c))

# %% [markdown]
# COMPLEX

# %%
d = 1j
print(d)
print(type(d))

# %% [markdown]
# LIST

# %%
e = ["a","b","c"]
print(e)
print(type(e))

# %% [markdown]
# TUPPLE

# %%
f = ("a","b","c")
print(f)
print(type(f))

# %% [markdown]
# RANGE

# %%
g = range(5)
print(g)
print(type(g))

# %% [markdown]
# SET

# %%
h = {"ani", "budi"}
print(h)
print(type(h))

# %% [markdown]
# DICT

# %%
i = {"nama" : "ani"}
print(i)
print(type(i))

# %% [markdown]
# FROZENSET

# %%
j = frozenset({"ani", "budi"})
print(j)
print(type(j))

# %% [markdown]
# BOOL

# %%
k = True
print(k)
print(type(k))

# %% [markdown]
# BYTES

# %%
l = b"hello"
print(l)
print(type(l))

# %% [markdown]
# BYTE ARRAY

# %%
m = bytearray(5)
print(m)
print(type(m))

# %% [markdown]
# MEMORY VIEW

# %%
n = memoryview(bytes(5))
print(n)
print(type(n))

# %% [markdown]
# NONE

# %%
o = None
print(o)
print(type(o))
